# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.preprocessing.image import array_to_img, img_to_array

from PIL import Image
from scipy import ndimage

import os, shutil

# %%
folder = 'images/'

# %%
hw_view = load_img('images/holllywood.jpeg')
hw_view
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=590x359 at 0x7FDF94E8ACA0>

# %%
ssign_view = load_img('images/Stop-Sign.jpeg')
# ssign_view

# %%
data_gen = ImageDataGenerator(rotation_range= 90)

# %%
data_gen.fit(images)

# %%
plot(data_gen)

# %%
from matplotlib.pyplot import imread, imshow, subplots, show

# %%
def plot(data_generator):
    """
    Plots 4 images generated by an object of the ImageDataGenerator class.
    """
    data_generator.fit(images)
    image_iterator = data_generator.flow(images)
    
    # Plot the images given by the iterator
    fig, rows = subplots(nrows=1, ncols=4, figsize=(18,18))
    for row in rows:
        row.imshow(image_iterator.next()[0].astype('int'))
        row.axis('off')
    show()
    
image = imread('images/holllywood.jpeg')

# Creating an array which contains just one image.
images = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))

imshow(images[0])
show()

# %%
images
# Out:
# array([[[[  2, 163, 218],
#          [  3, 164, 219],
#          [  5, 166, 221],
#          ...,
#          [  1, 160, 216],
#          [  1, 160, 216],
#          [  1, 160, 216]],
#
#         [[  3, 164, 219],
#          [  3, 164, 219],
#          [  5, 166, 221],
#          ...,
#          [  1, 160, 216],
#          [  1, 160, 216],
#          [  1, 160, 216]],
#
#         [[  3, 164, 219],
#          [  4, 165, 220],
#          [  4, 165, 220],
#          ...,
#          [  1, 160, 216],
#          [  1, 160, 216],
#          [  1, 160, 216]],
#
#         ...,
#
#         [[139,  87,  48],
#          [107,  54,  20],
#          [ 77,  23,   0],
#          ...,
#          [ 20,   2,   0],
#          [ 19,   1,   0],
#          [ 18,   2,   2]],
#
#         [[159, 104,  65],
#          [130,  76,  40],
#          [109,  54,  23],
#          ...,
#          [ 23,   5,   1],
#          [ 21,   3,   1],
#          [ 19,   3,   3]],
#
#         [[133,  75,  35],
# ...
